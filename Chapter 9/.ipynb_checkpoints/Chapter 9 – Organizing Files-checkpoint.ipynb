# %% [markdown]
# # Chapter 9 – Organizing Files
#
# ### The shutil module
#
# The `shutil` (or shell utilities) module has functions to let you copy, move, rename, and delete files in your Python programs.

# %%
import shutil

# %% [markdown]
# Calling `shutil.copy(source, destination)` will copy the file at the path source to the folder at the path destination. If destination is a filename, it will be used as the new name of the copied file. See the example:

# %%
import os
shutil.copy('spam.txt', './Example Folder/newfile.txt')
# Out:
# './Example Folder/newfile.txt'

# %% [markdown]
# While `shutil.copy()` will copy a single file, `shutil.copytree()` will copy an entire folder and every folder and file contained in it. Calling `shutil.copytree(source, destination)` will copy the folder at the path source, along with all of its files and subfolders, to the folder at the path destination.
#
# ```python3
# import shutil, os
# os.chdir('C:\\')
# shutil.copytree('C:\\bacon', 'C:\\bacon_backup')
# ```
# The `shutil.copytree()` call creates a new folder named bacon_backup with the same content as the original bacon folder.
#
# ### Moving and Renaming Files and Folders
#
# Calling `shutil.move(source, destination)` will move the file or folder at the path source to the path destination and will return a string of the absolute path of the new location.

# %%
shutil.move('./Example Folder/newfile.txt','.')
# Out:
# './newfile.txt'

# %% [markdown]
# If there's already a file on the destination folder with the same name as the file that you are moving, it will overwrite the file on the destination folder. To avoid this is important to rename the file that you are moving. See the example:

# %%
shutil.move('./spam.txt','./Example Folder/new_spam.txt')
# Out:
# './Example Folder/new_spam.txt'

# %% [markdown]
# Another point of attention is that is there's not a folder named after what you are pathing, the file that you are moving will change it's name to the folder name. (For example, if there isn't a folder named "Example Folder", the new file will have it's name as "Example Folder" and will no longer be a .txt). But if the whole pathing doesn't exists, python will send you an error message.
#
# ### Permanently Deleting Files and Folders
#
# - Calling `os.unlink(path)` will delete the file at path.
#
# - Calling `os.rmdir(path)` will delete the folder at path. This folder must be empty of any files or folders.
#
# - Calling `shutil.rmtree(path)` will remove the folder at path, and all files and folders it contains will also be deleted.
#
# It's most useful when you want to delete all the files with a specific extention, for example .pdf, .txt, by using the `.endswith` function. But this function is very dangerous and there's another way to exclude sending the files to trash.
#
#
# ### Safe Deletes with the send2trash Module
#
# See the example:

# %%
import send2trash
baconFile = open('bacon.txt', 'a') # creates the file
baconFile.write('Bacon is not a vegetable.')
baconFile.close()
send2trash.send2trash('bacon.txt') # send to the trash

# %% [markdown]
# Now you learned the two ways to remove files, one is used to remove completely and free the disk, the other is more secure but also leaves it trace on the computer and don't free the disk.
#
# ### Walking a Directory Tree
#
# Say you want to rename every file in some folder and also every file in every subfolder of that folder. That is, you want to walk through the directory tree, touching each file as you go. Writing a program to do this could get tricky; fortunately, Python provides a function to handle this process for you.
#
# Here's an example to walk through the directory:

# %%
for folderName, subfolders, filenames in os.walk('/home/vilasboasmv/Automate_Boring_Stuff'):
    print('The current folder is '+ folderName)
    for subfolder in subfolders:
        print('SUBFOLDER OF ' + folderName + ': ' + subfolder)
    for filename in filenames:
        print('FILE INSIDE:' + folderName + ': ' + filename)
print('')
# Out:
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff: .ipynb_checkpoints
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stu
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/objects/ed: 4e02c574db3c0cd44ba78e9409367e8b08c518
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/objects/c0
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/objects/c0: cd80b820264676b0fb21073c720f75c5619f0a
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/objects/c0: 3047087b46c3ede9cfe979d4a28693c50771e7
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/objects/info
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/objects/cc
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/objects/cc: 893713b0a59b520aaf5b865a0472717c6e1ed7
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/objects/29
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/objects/29: 130fee437a6479b8a9508751f69fe9f4118d22
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/hooks
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: post-update.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: prepare-commit-msg.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: update.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: applypatch-msg.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: pre-commit.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: commit-msg.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: fsmonitor-watchman.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: pre-applypatch.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: pre-receive.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: pre-rebase.sample
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/hooks: pre-push.sample
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/branches
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/logs
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/logs: refs
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/logs: HEAD
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs: heads
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs: remotes
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/heads
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/heads: master
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/remotes
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/remotes: origin
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/remotes/origin
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/remotes/origin: master
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/logs/refs/remotes/origin: HEAD
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/refs
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/refs: heads
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/refs: remotes
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/refs: tags
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/refs/heads
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/refs/heads: master
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/refs/remotes
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/.git/refs/remotes: origin
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/refs/remotes/origin
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/refs/remotes/origin: master
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/refs/remotes/origin: HEAD
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/refs/tags
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/.git/info
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/.git/info: exclude
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Exercise Regex Search
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Exercise Mad Libs
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Project Random Quiz Generator
# SUBFOLDER OF /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Projecct MultiClipboard
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Hello.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: mydata.dat
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: sonnet29.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: bacon.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: myCats.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: mydata.bak
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: mydata.dir
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8: Chapter 8 – Reading and Writing Files.ipynb
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Regex Search
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Regex Search: text2.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Regex Search: text1.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Regex Search: regexSearch.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Regex Search: text3.txt
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Mad Libs
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Mad Libs: madLibs.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Exercise Mad Libs: testing.txt
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers9.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz18.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz29.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers35.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz19.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers23.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz9.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers16.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz5.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers8.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz32.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz17.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz21.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers11.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers31.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz3.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz4.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers17.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz12.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers30.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz23.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz2.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers4.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers13.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers14.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers10.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz13.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers15.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz6.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers27.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers2.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz25.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers7.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz20.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz35.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz14.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz10.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers25.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers29.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers19.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers1.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers3.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers22.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers18.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz1.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz31.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers24.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz8.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers6.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers26.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers34.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: randomQuizGenerator.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers12.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz28.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers21.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz22.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz33.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz16.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz15.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers33.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz34.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz26.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers20.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz11.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz24.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers32.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers28.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz30.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz_answers5.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz7.txt
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Project Random Quiz Generator: capitalsquiz27.txt
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Projecct MultiClipboard
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Projecct MultiClipboard: mcb.dat
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Projecct MultiClipboard: mcb.bak
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Projecct MultiClipboard: mcb.dir
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 8/Projecct MultiClipboard: mcb.pyw
# The current folder is /home/vilasboasmv/Automate_Boring_Stuff/Chapter 7
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 7: StrongPassword.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 7: phoneAndEmail.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 7: RegexVersionStrip.py
# FILE INSIDE:/home/vilasboasmv/Automate_Boring_Stuff/Chapter 7: Cap 7 - Pattern Matching with Regular Expressions.ipynb

# %% [markdown]
# The `os.walk()` function is passed a single string value: the path of a folder. You can use `os.walk()` in a for loop statement to walk a directory tree, much like how you can use the `range()` function to walk over a range of numbers. Unlike `range()`, the `os.walk()` will return three values on each iteration through the loop:
#
# 1. A string of the current folder's name.
# 2. A list of strings of the folders in the current folder.
# 3. A list of strings of the files in the current folder.
